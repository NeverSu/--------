# %%
#!/usr/bin/env python  
# -*- coding: utf-8 -*-  
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SiHei']
plt.rcParams['axes.unicode_minus']=False  
print '打法撒'     
#matplotlib.use('qt4agg')  
x=pd.Series(np.exp(np.arange(20)))  
x.plot(label=u'sdad',legend=True)  
plt.show()  
x.plot(logy=True,label=u'对数据数据图',legend=True)  
plt.show()
# Out:
# 打法撒
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
